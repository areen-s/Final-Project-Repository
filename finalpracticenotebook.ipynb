# %%
# Import necessary modules
import random
import matplotlib.pyplot as plt 
import numpy as np

# %%
#will have 3 custom objects
#define individual class

class individual:
    """Class to hold information on individual Warbling Babblers"""
    
    def __init__(self,id, phenotype): 
    #the constructor will initialize the attributes phenotype and location of the individual
        self.id = id
        self.phenotype = phenotype
        
    
        
        
w_1=individual(id,"bright")
w_2=individual(id,"neutral")


    

    #somehow need to define defaults for individuals phenotype
# Out:
# 'bright'

# %%
#define population class
import random
import matplotlib.pyplot as plt 
import numpy as np

class individual:
    """Class to hold information on individual Warbling Babblers"""
    
    def __init__(self, phenotype,id): 
    #the constructor will initialize the attributes phenotype and location of the individual
        self.phenotype = phenotype
        self.id = id 
        
    
                    
    
class population: 
    """The population class will define how many individuals there are  """
    
    def __init__ (self,countbright,countneutral,popSize= 10):
        self.countbright = countbright
        self.countneutral = countneutral
        self.popSize = popSize
        
        
    
    def move(individual):
        """I want this method to randomly draw posititions for the individuals of the population and update their positions"""
        dirs = ["stay", "go"]
        move = random.choice(dirs) #randomly draws direction stay or go
        for individual in pop_1start:
            if move == "stay":
                pass
            elif move == "go":
                pop_1start.remove(0)
                pop_2start.append(w_1)
            else :
                pass
        
        for individual in pop_2start: 
            if move == "stay":
                pass
            elif move == "go":
                pop_1start.append(w_2)
                pop_2start.remove(0)
            else:
                pass



class landscape:
    """Class landscape will define the locations that the individuals in the population to move to/between"""

    def __init__(self, pop, size):
            self.pop = pop
            self.size = size
    
    def change(population):
        dirs = ["stay", "go"]
        move = random.choice(dirs)
        for individual in updated_pop_1:
            if w_1:
                if move == "stay":
                    pass
                elif move == "go":
                    updated_pop_1.pop(w_1)
                    updated_pop_2.append(w_1)
            if w_2:
                if move == "stay":
                    pass
                elif move == "go":
                    updated_pop_1.pop(w_2)
                    updated_pop_2.append(w_2)
        for individual in updated_pop_2:
                if w_1:
                    if move == "stay":
                        pass
                    elif move == "go":
                        updated_pop_2.pop(w_1)
                        updated_pop_1.append(w_1)
                if w_2:
                    if move == "stay":
                        pass
                    elif move == "go":
                        updated_pop_2.pop(w_2)
                        updated_pop_1.append(w_2)
                


  

        
w_1=individual("bright")
w_2=individual("neutral")

pop_1start=[w_1,w_1,w_1,w_1,w_1,w_1,w_1,w_1,w_1,w_1]
pop_2start=[w_2,w_2,w_2,w_2,w_2,w_2,w_2,w_2,w_2,w_2]
updated_pop_1=[]
updated_pop_2=[]

countbrightstartpop_1 = pop_1start.count(w_1)
countbrightstartpop_2 = pop_2start.count(w_1)
countneutralstartpop_1 = pop_1start.count(w_2)
countneutralstartpop_2 = pop_2start.count(w_2)

pop_1=population(countbrightstartpop_1,countneutralstartpop_1)
pop_2=population(countbrightstartpop_2,countneutralstartpop_2)


size = pop_1.popSize + pop_2.popSize
populations=[pop_1,pop_2]
landscape_1 = landscape(populations,size)

start = 1
weeks = 15

for individuals in pop_1start:
    pop_1.move()




import matplotlib.pyplot as plt
time_points = range(weeks + 1)
plt.plot(time_points, countbrightstartpop_1)
plt.plot(time_points, countbrightstartpop_2)
plt.plot(time_points, countneutralstartpop_1)
plt.plot(time_points, countneutralstartpop_2)
plt.xlabel('weeks')
plt.show()










        
        
        

       
 #updates individual with new id
    #sets the population size 
    
    
    
    #creates a list to store all the individuals in the population


    #populations need to start with a certain phenotype. once moving this will change and update 
    #list of individuals in the population will be kept here and updated
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-0491edb2a858> in <module>()
#     114
#     115 for individuals in pop_1start:
# --> 116     pop_1.move()
#     117
#     118
#
# <ipython-input-31-0491edb2a858> in move(individual)
#      31                 pass
#      32             elif move == "go":
# ---> 33                 pop_1start.remove(0)
#      34                 pop_2start.append(w_1)
#      35             else :
#
# ValueError: list.remove(x): x not in list

# %%
class landscape:
    """Class landscape will define the locations that the individuals in the population to move to/between"""

    def __init__(self, pop, size):
            self.pop = pop
            self.size = size


    def move(individual):
        """I want this method to randomly draw posititions for the individuals of the population and update their positions"""
        dirs = ["stay", "go"]
        move = random.choice(dirs) #randomly draws direction stay or go
        weeks = 15
        for i in range(weeks)
            for individual in pop_1start:
                if move == "stay":
                    updated_pop_1 = pop_1start
                    updated_pop_2 = pop_2start
                elif move == "go":
                    updated_pop_1 = pop_1start.remove()
                    updated_pop_2 = pop_2start.append()   
            for individual in pop_2start: 
                if move == "stay":
                    updated_pop_1 = pop_1start
                    updated_pop_2 = pop_2start
                elif move == "go":
                    updated_pop_1 = pop_1start.append()
                    updated_pop_2 = pop_2start.remove() 
                
for individual in pop_1.individuals: 
    individual.move()
for individual in pop_2.individuals: 
    individual.move()
        
size = population_1.popSize + population_2.popSize
populations=[population_1,population_2]
landscape_1 = landscape(populations,size)


        

    #provide landscapes for the individuals in the population to move to 
    #list for populations in each landscape

#needs to be a list for new population drawn 

    

#probably need code to draw from a new individual to move each time 


            
        
        #here we want to make the individual stay in population 1 and
        #keep the population size the same 
        
   
        #here we want to make the individual move to population 2
        #increase the size of population 2 without changing the phenotype of that individual 
        #and decrease the population 1 size by -1
        
    
        #here we want to make the individual stay in population 2 and 
        #keep population size the same 
        
    
        #here we want to make the individual move to population 1
        #increase the size of population 1 without changing the phenotype of that individual
        #and decrease the population 2 size by -1
        

              
          
    #need to have population 1 and 2. each originally containing the phenotype neutral and bright to begin with.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-45-3452e617368a> in <module>()
#      25
#      26
# ---> 27 for individual in pop_1.individuals:
#      28     individual.move()
#      29 for individual in pop_2.individuals:
#
# AttributeError: 'population' object has no attribute 'individuals'

# %%
#define population class
import random
import matplotlib.pyplot as plt 
import numpy as np

class individual:
    """Class to hold information on individual Warbling Babblers"""
    
    def __init__(self, phenotype,id): 
    #the constructor will initialize the attributes phenotype and location of the individual
        self.phenotype = phenotype
        self.id = id 
        

    
                    
    
class population: 
    """The population class will define how many individuals there are  """
    
    def __init__ (self,mapSize =10,popSize= 10):
        self.mapSize = mapSize
        self.popSize = popSize
        self.individuals=[]
            
        
    
    def move(individual):
        """I want this method to randomly draw posititions for the individuals of the population and update their positions"""
        dirs = ["stay", "go"]
        move = random.choice(dirs) #randomly draws direction stay or go
        for individiduals in pop_1.individuals:
            if move == "stay":
                pass
            elif move == "go" :
                pop_1.individuals.remove(individual)
                pop_2.individuals.append()
            else :
                pass
        
        for individuals in pop_2.individuals :
            if move == "stay":
                pass
            elif move == "go":
                pop_1.individuals.append()
                pop_2.individuals.remove()
            else:
                pass



class landscape:
    """Class landscape will define the locations that the individuals in the population to move to/between"""

    def __init__(self, pop, size):
            self.pop = pop
            self.size = size
    
    def change(population):
        dirs = ["stay", "go"]
        move = random.choice(dirs)
        for individual in updated_pop_1:
            if w_1:
                if move == "stay":
                    pass
                elif move == "go":
                    updated_pop_1.pop(w_1)
                    updated_pop_2.append(w_1)
            if w_2:
                if move == "stay":
                    pass
                elif move == "go":
                    updated_pop_1.pop(w_2)
                    updated_pop_2.append(w_2)
        for individual in updated_pop_2:
                if w_1:
                    if move == "stay":
                        pass
                    elif move == "go":
                        updated_pop_2.pop(w_1)
                        updated_pop_1.append(w_1)
                if w_2:
                    if move == "stay":
                        pass
                    elif move == "go":
                        updated_pop_2.pop(w_2)
                        updated_pop_1.append(w_2)

w_1=individual("bright",id)
w_2=individual("neutral",id)

pop_1=population()
pop_2=population()
pop_1.individuals=[]

# %%
    def move(self): 
        """Method will randomly draw a position for individual to move to and update the x and y coordinates accordingly"""
        
        # Similar to the code from week 8, the code in this method should cause an
        # individual to move one unit up, down, left, or right (chosen randomly).
        # The x and y coordinates for this individual should be modified accordingly.
        dirs = ["u","d","l","r"]
        move = random.choice(dirs) # Randomly draws a direction - u, d, l, or r
        if move == "u":# Test what direction was drawn and update position accordingly
            self.y=self.y + 1
        elif move == "d":
            self.y=self.y - 1
        elif move == "l":
            self.x=self.x - 1
        elif move == "r":
            self.x=self.x + 1
        else:
            print("Something is wrong! Direction is not u, d, l, or r.")

        
    def printLocation(self): # Add necessary arguments
        """Method will print a text description of the individual's id and location in coordinates x and y"""
        
        # This method should print a text description of the 
        # individual's id and location (x,y).
        print("The individual with id %s has the location of (%f, %f)." % (self.id, self.x, self.y))
# Out:
#   File "<ipython-input-6-46efe2c24d0e>", line 2
#     def move(self):
#     ^
# IndentationError: unexpected indent

# %%
# Define the population class

class population:
    """Class to hold information on population"""
    
    
    def __init__(self, mapSize=10, popSize=10): # Add default values.
        """Constructor for population class. Map size and population size are variables"""
        
        # This constructor should create a list of individuals in the population. The 
        # number of individuals should be equal to popSize and each individual should have
        # a unique id. The constructor should also record the mapSize as an attribute.
        self.mapSize= mapSize
        self.popSize= popSize
        
        self.individuals=[] #create a list to store all individuals in population
        
        for i in range(popSize): #this will loop the number of individuals to be within the population size 
            self.individuals.append(individual(id=i+1)) #updates individual with new id

        
    def move(self): # Add necessary arguments
        """Constructor to move an individual within the population's position"""
        
        # The code in this method should use a for loop and cause each individual to 
        # move one unit up, down, left, or right. This code should call the .move() method
        # of each individual.
        for individual in self.individuals:
            individual.move() #calls move method

        
    def listLocations(self): # Add necessary arguments
        """Printing location of each individual"""
        
        # The code in this method should use a for loop to print a text description of
        # each individual's location. This code should call the .printLocation() method
        # of each individual.
        for individual in self.individuals:
            individual.printLocation() #calls print.Location method
        
    def draw(self): # Add necessary arguments
        """Creates a plot to show the locations of individuals in this population"""
        
        # The code in this method should use the .plot() method from pyplot to 
        # create a scatterplot showing the locations of all individuals in this
        # population. The length of the x- and y-axes should each by mapSize.
        plt.figure() 
        for individual in self.individuals: 
            plt.scatter(x= individual.x, y= individual.y)
            plt.title('Location After Dispersal')
        plt.show

# %%
# Create a new population with default values
pop = population()
# Assign the number of time steps that individuals will move
steps = 10
# Use a for loop to simulate the movement of individuals for the specified number of steps.
for i in range(steps):
    pop.move()
# Use the .draw() method of the population to draw the map.
pop.draw()
# Use the .listLocations() method to list the locations of all individuals in the population.
pop.listLocations()

# %%
# Try creating a new population, simulating the movement of individuals, drawing a map,
# and listing the location of individuals, but provide non-default values for the mapSize
# and popSize of the population. Also, increase the number of time steps that individuals move.
popNew = population(mapSize= 15, popSize= 15)
steps= 20
for i in range(steps):
    popNew.move()
popNew.draw()
popNew.listLocations()
